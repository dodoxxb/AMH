# %%
import os
import random
import pandas as pd
import numpy as np
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import KFold
from collections import Counter
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import f1_score
from sklearn import linear_model
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from imblearn.over_sampling import ADASYN
from imblearn.under_sampling import RandomUnderSampler 
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
from sklearn.svm import OneClassSVM
from sklearn.ensemble import IsolationForest
from sklearn.covariance import EllipticEnvelope
from sklearn.neighbors import LocalOutlierFactor
from sklearn.metrics import accuracy_score
from sklearn import preprocessing
from imblearn.over_sampling import SVMSMOTE 
from imblearn.under_sampling import InstanceHardnessThreshold

# %%
def get_face_landmarks(csv_path):
    df = pd.read_csv(csv_path, usecols=[1,2,3])
    # print(df.head(10))
    df_x = df['x']
    df_y = df['y']
    df_z = df['z']
    face_x = df_x.values.tolist()
    face_y = df_y.values.tolist()
    face_z = df_z.values.tolist()

    print("There are {num} faces recorded from this sample.".format(num = np.array(face_x).shape[0] / 468))
    print(np.array(face_x).shape)

    return face_x, face_y, face_z, (np.array(face_x).shape[0] / 468)


def get_avg_face_landmarks(x, y, z, face_num):
    avg_x = []
    avg_y = []
    avg_z = []

    for i in range(468):
        temp = x[i:len(x):468]
        avg_x.append(np.sum(temp)/face_num)
    for i in range(468):
        temp = y[i:len(x):468]
        avg_y.append(np.sum(temp)/face_num)
    for i in range(468):
        temp = z[i:len(x):468]
        avg_z.append(np.sum(temp)/face_num)

    print(np.array(avg_x).shape)
    return avg_x, avg_y, avg_z

# %%
root = os.path.dirname(os.getcwd())
print("root direction", root)

label_path = root + '/muldataset/labels.csv'
print(label_path)

df = pd.read_csv(label_path)
# print(df)
df_folder = df['folder'].values.tolist()
df_dep = df['depression'].values.tolist()
df_inter = df['interpersonal tension'].values.tolist()
df_anx = df['anxiety'].values.tolist()
df_obs = df['obsessive-compulsive'].values.tolist()
df_par = df['paranoia'].values.tolist()
df_hos = df['hostility'].values.tolist()
df_aca = df['academic stress'].values.tolist()
df_mal = df['maladjustment'].values.tolist()
df_emo = df['emotional imbalance'].values.tolist()
df_psy = df['psychological imbalance'].values.tolist()
df_label = df['overall condition'].values.tolist()
df_sui = df['suicidal tendency'].values.tolist()
# print(df_folder)
labels = df_label
# Out:
# root direction f:\Project\AMH
# f:\Project\AMH/muldataset/labels.csv

# %%
if __name__ == '__main__':
    face = []

    root = os.path.dirname(os.getcwd())
    print("root direction", root)
    dataset = os.listdir(root + '/muldataset')
    del dataset[-1]
    for sample in dataset:
        sample_path = root + '/muldataset' + '/' + sample #样本文件夹
        # print(sample_path)
        sample_file = os.listdir(sample_path) #样本文件夹内文件列表
        # print(sample_file)
        for detail in sample_file:
                sample_path = root + '/muldataset' + '/' + sample
                if 'face_landmarks' in detail:
                    # 打开csv文件并读取人脸信息
                    print(sample_path + '/' + detail)
                    face_x, face_y, face_z, face_num = get_face_landmarks(sample_path + '/' + detail)
                    avg_x, avg_y, avg_z = get_avg_face_landmarks(face_x, face_y, face_z, face_num)
                    temp_face = avg_x + avg_y + avg_z
                    face.append(temp_face)
                    print(np.array(face).shape)

    # print(face)
    print(np.array(face).shape)
    # print(labels)
    print(np.array(labels).shape)
# Out:
# root direction f:\Project\AMH
# f:\Project\AMH/muldataset/00002-0101/face_landmarks.csv
# There are 212.0 faces recorded from this sample.
# (99216,)
# (468,)
# (1, 1404)
# f:\Project\AMH/muldataset/00002-0102/face_landmarks.csv
# There are 227.0 faces recorded from this sample.
# (106236,)
# (468,)
# (2, 1404)
# f:\Project\AMH/muldataset/00002-0103/face_landmarks.csv
# There are 158.0 faces recorded from this sample.
# (73944,)
# (468,)
# (3, 1404)
# f:\Project\AMH/muldataset/00002-0104/face_landmarks.csv
# There are 195.0 faces recorded from this sample.
# (91260,)
# (468,)
# (4, 1404)
# f:\Project\AMH/muldataset/00002-0105/face_landmarks.csv
# There are 248.0 faces recorded from this sample.
# (116064,)
# (468,)
# (5, 1404)
# f:\Project\AMH/muldataset/00002-0106/face_landmarks.csv
# There are 216.0 faces recorded from this sample.
# (101088,)
# (468,)
# (6, 1404)
# f:\Project\AMH/muldataset/00002-0107/face_landmarks.csv
# There are 291.0 faces recorded from this sample.
# (136188,)
# (468,)
# (7, 1404)
# f:\Project\AMH/muldataset/00002-0108/face_landmarks.csv
# There are 258.0 faces recorded from this sample.
# (120744,)
# (468,)
# (8, 1404)
# f:\Project\AMH/muldataset/00002-0109/face_landmarks.csv
# There are 202.0 faces recorded from this sample.
# (94536,)
# (468,)
# (9, 1404)
# f:\Project\AMH/muldataset/00002-0110/face_landmarks.csv
# There are 263.0 faces recorded from this sample.
# (123084,)
# (468,)
# (10, 1404)
# f:\Project\AMH/muldataset/00002-0111/face_landmarks.csv
# There are 235.0 faces recorded from this sample.
# (109980,)
# (468,)
# (11, 1404)
# f:\Project\AMH/muldataset/00002-0112/face_landmarks.csv
# There are 121.0 faces recorded from this sample.
# (56628,)
# (468,)
# (12, 1404)
# f:\Project\AMH/muldataset/00002-0113/face_landmarks.csv
# There are 252.0 faces recorded from this sample.
# (117936,)
# (468,)
# (13, 1404)
# f:\Project\AMH/muldataset/00002-0114/face_landmarks.csv
# There are 235.0 faces recorded from this sample.
# (109980,)
# (468,)
# (14, 1404)
# f:\Project\AMH/muldataset/00002-0115/face_landmarks.csv
# There are 241.0 faces recorded from this sample.
# (112788,)
# (468,)
# (15, 1404)
# f:\Project\AMH/muldataset/00002-0116/face_landmarks.csv
# There are 205.0 faces recorded from this sample.
# (95940,)
# (468,)
# (16, 1404)
# f:\Project\AMH/muldataset/00002-0117/face_landmarks.csv
# There are 211.0 faces recorded from this sample.
# (98748,)
# (468,)
# (17, 1404)
# f:\Project\AMH/muldataset/00002-0118/face_landmarks.csv
# There are 222.0 faces recorded from this sample.
# (103896,)
# (468,)
# (18, 1404)
# f:\Project\AMH/muldataset/00002-0119/face_landmarks.csv
# There are 28.0 faces recorded from this sample.
# (13104,)
# (468,)
# (19, 1404)
# f:\Project\AMH/muldataset/00002-0120/face_landmarks.csv
# There are 260.0 faces recorded from this sample.
# (121680,)
# (468,)
# (20, 1404)
# f:\Project\AMH/muldataset/00002-0121/face_landmarks.csv
# There are 230.0 faces recorded from this sample.
# (107640,)
# (468,)
# (21, 1404)
# f:\Project\AMH/muldataset/00002-0122/face_landmarks.csv
# There are 258.0 faces recorded from this sample.
# (120744,)
# (468,)
# (22, 1404)
# f:\Project\AMH/muldataset/00002-0123/face_landmarks.csv
# There are 247.0 faces recorded from this sample.
# (115596,)
# (468,)
# (23, 1404)
# f:\Project\AMH/muldataset/00002-0124/face_landmarks.csv
# There are 23.0 faces recorded from this sample.
# (10764,)
# (468,)
# (24, 1404)
# f:\Project\AMH/muldataset/00002-0125/face_landmarks.csv
# There are 237.0 faces recorded from this sample.
# (110916,)
# (468,)
# (25, 1404)
# f:\Project\AMH/muldataset/00002-0126/face_landmarks.csv
# There are 219.0 faces recorded from this sample.
# (102492,)
# (468,)
# (26, 1404)
# f:\Project\AMH/muldataset/00002-0127/face_landmarks.csv
# There are 127.0 faces recorded from this sample.
# (59436,)
# (468,)
# (27, 1404)
# f:\Project\AMH/muldataset/00002-0128/face_landmarks.csv
# There are 268.0 faces recorded from this sample.
# (125424,)
# (468,)
# (28, 1404)
# f:\Project\AMH/muldataset/00002-0129/face_landmarks.csv
# There are 171.0 faces recorded from this sample.
# (80028,)
# (468,)
# (29, 1404)
# f:\Project\AMH/muldataset/00002-0130/face_landmarks.csv
# There are 70.0 faces recorded from this sample.
# (32760,)
# (468,)
# (30, 1404)
# f:\Project\AMH/muldataset/00002-0131/face_landmarks.csv
# There are 114.0 faces recorded from this sample.
# (53352,)
# (468,)
# (31, 1404)
# f:\Project\AMH/muldataset/00002-0132/face_landmarks.csv
# There are 255.0 faces recorded from this sample.
# (119340,)
# (468,)
# (32, 1404)
# f:\Project\AMH/muldataset/00002-0133/face_landmarks.csv
# There are 16.0 faces recorded from this sample.
# (7488,)
# (468,)
# (33, 1404)
# f:\Project\AMH/muldataset/00002-0134/face_landmarks.csv
# There are 203.0 faces recorded from this sample.
# (95004,)
# (468,)
# (34, 1404)
# f:\Project\AMH/muldataset/00002-0135/face_landmarks.csv
# There are 271.0 faces recorded from this sample.
# (126828,)
# (468,)
# (35, 1404)
# f:\Project\AMH/muldataset/00002-0136/face_landmarks.csv
# There are 54.0 faces recorded from this sample.
# (25272,)
# (468,)
# (36, 1404)
# f:\Project\AMH/muldataset/00002-0137/face_landmarks.csv
# There are 182.0 faces recorded from this sample.
# (85176,)
# (468,)
# (37, 1404)
# f:\Project\AMH/muldataset/00002-0138/face_landmarks.csv
# There are 149.0 faces recorded from this sample.
# (69732,)
# (468,)
# (38, 1404)
# f:\Project\AMH/muldataset/00002-0139/face_landmarks.csv
# There are 125.0 faces recorded from this sample.
# (58500,)
# (468,)
# (39, 1404)
# f:\Project\AMH/muldataset/00002-0140/face_landmarks.csv
# There are 202.0 faces recorded from this sample.
# (94536,)
# (468,)
# (40, 1404)
# f:\Project\AMH/muldataset/00002-0201/face_landmarks.csv
# There are 28.0 faces recorded from this sample.
# (13104,)
# (468,)
# (41, 1404)
# f:\Project\AMH/muldataset/00002-0202/face_landmarks.csv
# There are 123.0 faces recorded from this sample.
# (57564,)
# (468,)
# (42, 1404)
# f:\Project\AMH/muldataset/00002-0204/face_landmarks.csv
# There are 43.0 faces recorded from this sample.
# (20124,)
# (468,)
# (43, 1404)
# f:\Project\AMH/muldataset/00002-0205/face_landmarks.csv
# There are 44.0 faces recorded from this sample.
# (20592,)
# (468,)
# (44, 1404)
# f:\Project\AMH/muldataset/00002-0206/face_landmarks.csv
# There are 102.0 faces recorded from this sample.
# (47736,)
# (468,)
# (45, 1404)
# f:\Project\AMH/muldataset/00002-0207/face_landmarks.csv
# There are 177.0 faces recorded from this sample.
# (82836,)
# (468,)
# (46, 1404)
# f:\Project\AMH/muldataset/00002-0208/face_landmarks.csv
# There are 58.0 faces recorded from this sample.
# (27144,)
# (468,)
# (47, 1404)
# f:\Project\AMH/muldataset/00002-0209/face_landmarks.csv
# There are 114.0 faces recorded from this sample.
# (53352,)
# (468,)
# (48, 1404)
# f:\Project\AMH/muldataset/00002-0210/face_landmarks.csv
# There are 165.0 faces recorded from this sample.
# (77220,)
# (468,)
# (49, 1404)
# f:\Project\AMH/muldataset/00002-0211/face_landmarks.csv
# There are 99.0 faces recorded from this sample.
# (46332,)
# (468,)
# (50, 1404)
# f:\Project\AMH/muldataset/00002-0212/face_landmarks.csv
# There are 213.0 faces recorded from this sample.
# (99684,)
# (468,)
# (51, 1404)
# f:\Project\AMH/muldataset/00002-0213/face_landmarks.csv
# There are 269.0 faces recorded from this sample.
# (125892,)
# (468,)
# (52, 1404)
# f:\Project\AMH/muldataset/00002-0214/face_landmarks.csv
# There are 96.0 faces recorded from this sample.
# (44928,)
# (468,)
# (53, 1404)
# f:\Project\AMH/muldataset/00002-0215/face_landmarks.csv
# There are 32.0 faces recorded from this sample.
# (14976,)
# (468,)
# (54, 1404)
# f:\Project\AMH/muldataset/00002-0216/face_landmarks.csv
# There are 167.0 faces recorded from this sample.
# (78156,)
# (468,)
# (55, 1404)
# f:\Project\AMH/muldataset/00002-0217/face_landmarks.csv
# There are 150.0 faces recorded from this sample.
# (70200,)
# (468,)
# (56, 1404)
# f:\Project\AMH/muldataset/00002-0219/face_landmarks.csv
# There are 99.0 faces recorded from this sample.
# (46332,)
# (468,)
# (57, 1404)
# f:\Project\AMH/muldataset/00002-0221/face_landmarks.csv
# There are 153.0 faces recorded from this sample.
# (71604,)
# (468,)
# (58, 1404)
# f:\Project\AMH/muldataset/00002-0223/face_landmarks.csv
# There are 228.0 faces recorded from this sample.
# (106704,)
# (468,)
# (59, 1404)
# f:\Project\AMH/muldataset/00002-0224/face_landmarks.csv
# There are 171.0 faces recorded from this sample.
# (80028,)
# (468,)
# (60, 1404)
# f:\Project\AMH/muldataset/00002-0225/face_landmarks.csv
# There are 113.0 faces recorded from this sample.
# (52884,)
# (468,)
# (61, 1404)
# f:\Project\AMH/muldataset/00002-0226/face_landmarks.csv
# There are 250.0 faces recorded from this sample.
# (117000,)
# (468,)
# (62, 1404)
# f:\Project\AMH/muldataset/00002-0227/face_landmarks.csv
# There are 154.0 faces recorded from this sample.
# (72072,)
# (468,)
# (63, 1404)
# f:\Project\AMH/muldataset/00002-0229/face_landmarks.csv
# There are 195.0 faces recorded from this sample.
# (91260,)
# (468,)
# (64, 1404)
# f:\Project\AMH/muldataset/00002-0230/face_landmarks.csv
# There are 193.0 faces recorded from this sample.
# (90324,)
# (468,)
# (65, 1404)
# f:\Project\AMH/muldataset/00002-0231/face_landmarks.csv
# There are 100.0 faces recorded from this sample.
# (46800,)
# (468,)
# (66, 1404)
# f:\Project\AMH/muldataset/00002-0233/face_landmarks.csv
# There are 250.0 faces recorded from this sample.
# (117000,)
# (468,)
# (67, 1404)
# f:\Project\AMH/muldataset/00002-0234/face_landmarks.csv
# There are 291.0 faces recorded from this sample.
# (136188,)
# (468,)
# (68, 1404)
# f:\Project\AMH/muldataset/00002-0235/face_landmarks.csv
# There are 217.0 faces recorded from this sample.
# (101556,)
# (468,)
# (69, 1404)
# f:\Project\AMH/muldataset/00002-0236/face_landmarks.csv
# There are 129.0 faces recorded from this sample.
# (60372,)
# (468,)
# (70, 1404)
# f:\Project\AMH/muldataset/00002-0237/face_landmarks.csv
# There are 151.0 faces recorded from this sample.
# (70668,)
# (468,)
# (71, 1404)
# f:\Project\AMH/muldataset/00002-0238/face_landmarks.csv
# There are 262.0 faces recorded from this sample.
# (122616,)
# (468,)
# (72, 1404)
# f:\Project\AMH/muldataset/00002-0239/face_landmarks.csv
# There are 92.0 faces recorded from this sample.
# (43056,)
# (468,)
# (73, 1404)
# f:\Project\AMH/muldataset/00002-0240/face_landmarks.csv
# There are 107.0 faces recorded from this sample.
# (50076,)
# (468,)
# (74, 1404)
# f:\Project\AMH/muldataset/00002-0241/face_landmarks.csv
# There are 218.0 faces recorded from this sample.
# (102024,)
# (468,)
# (75, 1404)
# f:\Project\AMH/muldataset/00002-0301/face_landmarks.csv
# There are 264.0 faces recorded from this sample.
# (123552,)
# (468,)
# (76, 1404)
# f:\Project\AMH/muldataset/00002-0303/face_landmarks.csv
# There are 56.0 faces recorded from this sample.
# (26208,)
# (468,)
# (77, 1404)
# f:\Project\AMH/muldataset/00002-0304/face_landmarks.csv
# There are 19.0 faces recorded from this sample.
# (8892,)
# (468,)
# (78, 1404)
# f:\Project\AMH/muldataset/00002-0305/face_landmarks.csv
# There are 217.0 faces recorded from this sample.
# (101556,)
# (468,)
# (79, 1404)
# f:\Project\AMH/muldataset/00002-0306/face_landmarks.csv
# There are 109.0 faces recorded from this sample.
# (51012,)
# (468,)
# (80, 1404)
# f:\Project\AMH/muldataset/00002-0307/face_landmarks.csv
# There are 78.0 faces recorded from this sample.
# (36504,)
# (468,)
# (81, 1404)
# f:\Project\AMH/muldataset/00002-0308/face_landmarks.csv
# There are 425.0 faces recorded from this sample.
# (198900,)
# (468,)
# (82, 1404)
# f:\Project\AMH/muldataset/00002-0309/face_landmarks.csv
# There are 135.0 faces recorded from this sample.
# (63180,)
# (468,)
# (83, 1404)
# f:\Project\AMH/muldataset/00002-0310/face_landmarks.csv
# There are 218.0 faces recorded from this sample.
# (102024,)
# (468,)
# (84, 1404)
# f:\Project\AMH/muldataset/00002-0311/face_landmarks.csv
# There are 43.0 faces recorded from this sample.
# (20124,)
# (468,)
# (85, 1404)
# f:\Project\AMH/muldataset/00002-0312/face_landmarks.csv
# There are 184.0 faces recorded from this sample.
# (86112,)
# (468,)
# (86, 1404)
# f:\Project\AMH/muldataset/00002-0313/face_landmarks.csv
# There are 130.0 faces recorded from this sample.
# (60840,)
# (468,)
# (87, 1404)
# f:\Project\AMH/muldataset/00002-0314/face_landmarks.csv
# There are 269.0 faces recorded from this sample.
# (125892,)
# (468,)
# (88, 1404)
# f:\Project\AMH/muldataset/00002-0315/face_landmarks.csv
# There are 238.0 faces recorded from this sample.
# (111384,)
# (468,)
# (89, 1404)
# f:\Project\AMH/muldataset/00002-0316/face_landmarks.csv
# There are 244.0 faces recorded from this sample.
# (114192,)
# (468,)
# (90, 1404)
# f:\Project\AMH/muldataset/00002-0317/face_landmarks.csv
# There are 248.0 faces recorded from this sample.
# (116064,)
# (468,)
# (91, 1404)
# f:\Project\AMH/muldataset/00002-0318/face_landmarks.csv
# There are 112.0 faces recorded from this sample.
# (52416,)
# (468,)
# (92, 1404)
# f:\Project\AMH/muldataset/00002-0319/face_landmarks.csv
# There are 66.0 faces recorded from this sample.
# (30888,)
# (468,)
# (93, 1404)
# f:\Project\AMH/muldataset/00002-0320/face_landmarks.csv
# There are 283.0 faces recorded from this sample.
# (132444,)
# (468,)
# (94, 1404)
# f:\Project\AMH/muldataset/00002-0321/face_landmarks.csv
# There are 246.0 faces recorded from this sample.
# (115128,)
# (468,)
# (95, 1404)
# f:\Project\AMH/muldataset/00002-0322/face_landmarks.csv
# There are 115.0 faces recorded from this sample.
# (53820,)
# (468,)
# (96, 1404)
# f:\Project\AMH/muldataset/00002-0323/face_landmarks.csv
# There are 182.0 faces recorded from this sample.
# (85176,)
# (468,)
# (97, 1404)
# f:\Project\AMH/muldataset/00002-0324/face_landmarks.csv
# There are 144.0 faces recorded from this sample.
# (67392,)
# (468,)
# (98, 1404)
# f:\Project\AMH/muldataset/00002-0325/face_landmarks.csv
# There are 131.0 faces recorded from this sample.
# (61308,)
# (468,)
# (99, 1404)
# f:\Project\AMH/muldataset/00002-0326/face_landmarks.csv
# There are 188.0 faces recorded from this sample.
# (87984,)
# (468,)
# (100, 1404)
# f:\Project\AMH/muldataset/00002-0327/face_landmarks.csv
# There are 184.0 faces recorded from this sample.
# (86112,)
# (468,)
# (101, 1404)
# f:\Project\AMH/muldataset/00002-0328/face_landmarks.csv
# There are 143.0 faces recorded from this sample.
# (66924,)
# (468,)
# (102, 1404)
# f:\Project\AMH/muldataset/00002-0329/face_landmarks.csv
# There are 243.0 faces recorded from this sample.
# (113724,)
# (468,)
# (103, 1404)
# f:\Project\AMH/muldataset/00002-0330/face_landmarks.csv
# There are 40.0 faces recorded from this sample.
# (18720,)
# (468,)
# (104, 1404)
# f:\Project\AMH/muldataset/00002-0331/face_landmarks.csv
# There are 147.0 faces recorded from this sample.
# (68796,)
# (468,)
# (105, 1404)
# f:\Project\AMH/muldataset/00002-0332/face_landmarks.csv
# There are 46.0 faces recorded from this sample.
# (21528,)
# (468,)
# (106, 1404)
# f:\Project\AMH/muldataset/00002-0333/face_landmarks.csv
# There are 236.0 faces recorded from this sample.
# (110448,)
# (468,)
# (107, 1404)
# f:\Project\AMH/muldataset/00002-0334/face_landmarks.csv
# There are 191.0 faces recorded from this sample.
# (89388,)
# (468,)
# (108, 1404)
# f:\Project\AMH/muldataset/00002-0335/face_landmarks.csv
# There are 124.0 faces recorded from this sample.
# (58032,)
# (468,)
# (109, 1404)
# f:\Project\AMH/muldataset/00002-0337/face_landmarks.csv
# There are 233.0 faces recorded from this sample.
# (109044,)
# (468,)
# (110, 1404)
# f:\Project\AMH/muldataset/00002-0338/face_landmarks.csv
# There are 293.0 faces recorded from this sample.
# (137124,)
# (468,)
# (111, 1404)
# f:\Project\AMH/muldataset/00002-0340/face_landmarks.csv
# There are 34.0 faces recorded from this sample.
# (15912,)
# (468,)
# (112, 1404)
# f:\Project\AMH/muldataset/00002-0341/face_landmarks.csv
# There are 269.0 faces recorded from this sample.
# (125892,)
# (468,)
# (113, 1404)
# f:\Project\AMH/muldataset/00002-0401/face_landmarks.csv
# There are 125.0 faces recorded from this sample.
# (58500,)
# (468,)
# (114, 1404)
# f:\Project\AMH/muldataset/00002-0402/face_landmarks.csv
# There are 312.0 faces recorded from this sample.
# (146016,)
# (468,)
# (115, 1404)
# f:\Project\AMH/muldataset/00002-0404/face_landmarks.csv
# There are 138.0 faces recorded from this sample.
# (64584,)
# (468,)
# (116, 1404)
# f:\Project\AMH/muldataset/00002-0405/face_landmarks.csv
# There are 238.0 faces recorded from this sample.
# (111384,)
# (468,)
# (117, 1404)
# f:\Project\AMH/muldataset/00002-0406/face_landmarks.csv
# There are 27.0 faces recorded from this sample.
# (12636,)
# (468,)
# (118, 1404)
# f:\Project\AMH/muldataset/00002-0407/face_landmarks.csv
# There are 224.0 faces recorded from this sample.
# (104832,)
# (468,)
# (119, 1404)
# f:\Project\AMH/muldataset/00002-0408/face_landmarks.csv
# There are 157.0 faces recorded from this sample.
# (73476,)
# (468,)
# (120, 1404)
# f:\Project\AMH/muldataset/00002-0409/face_landmarks.csv
# There are 148.0 faces recorded from this sample.
# (69264,)
# (468,)
# (121, 1404)
# f:\Project\AMH/muldataset/00002-0410/face_landmarks.csv
# There are 139.0 faces recorded from this sample.
# (65052,)
# (468,)
# (122, 1404)
# f:\Project\AMH/muldataset/00002-0411/face_landmarks.csv
# There are 212.0 faces recorded from this sample.
# (99216,)
# (468,)
# (123, 1404)
# f:\Project\AMH/muldataset/00002-0412/face_landmarks.csv
# There are 136.0 faces recorded from this sample.
# (63648,)
# (468,)
# (124, 1404)
# f:\Project\AMH/muldataset/00002-0413/face_landmarks.csv
# There are 329.0 faces recorded from this sample.
# (153972,)
# (468,)
# (125, 1404)
# f:\Project\AMH/muldataset/00002-0414/face_landmarks.csv
# There are 208.0 faces recorded from this sample.
# (97344,)
# (468,)
# (126, 1404)
# f:\Project\AMH/muldataset/00002-0415/face_landmarks.csv
# There are 308.0 faces recorded from this sample.
# (144144,)
# (468,)
# (127, 1404)
# f:\Project\AMH/muldataset/00002-0416/face_landmarks.csv
# There are 32.0 faces recorded from this sample.
# (14976,)
# (468,)
# (128, 1404)
# f:\Project\AMH/muldataset/00002-0417/face_landmarks.csv
# There are 162.0 faces recorded from this sample.
# (75816,)
# (468,)
# (129, 1404)
# f:\Project\AMH/muldataset/00002-0418/face_landmarks.csv
# There are 169.0 faces recorded from this sample.
# (79092,)
# (468,)
# (130, 1404)
# f:\Project\AMH/muldataset/00002-0419/face_landmarks.csv
# There are 334.0 faces recorded from this sample.
# (156312,)
# (468,)
# (131, 1404)
# f:\Project\AMH/muldataset/00002-0420/face_landmarks.csv
# There are 276.0 faces recorded from this sample.
# (129168,)
# (468,)
# (132, 1404)
# f:\Project\AMH/muldataset/00002-0421/face_landmarks.csv
# There are 237.0 faces recorded from this sample.
# (110916,)
# (468,)
# (133, 1404)
# f:\Project\AMH/muldataset/00002-0422/face_landmarks.csv
# There are 82.0 faces recorded from this sample.
# (38376,)
# (468,)
# (134, 1404)
# f:\Project\AMH/muldataset/00002-0423/face_landmarks.csv
# There are 310.0 faces recorded from this sample.
# (145080,)
# (468,)
# (135, 1404)
# f:\Project\AMH/muldataset/00002-0424/face_landmarks.csv
# There are 301.0 faces recorded from this sample.
# (140868,)
# (468,)
# (136, 1404)
# f:\Project\AMH/muldataset/00002-0425/face_landmarks.csv
# There are 62.0 faces recorded from this sample.
# (29016,)
# (468,)
# (137, 1404)
# f:\Project\AMH/muldataset/00002-0426/face_landmarks.csv
# There are 248.0 faces recorded from this sample.
# (116064,)
# (468,)
# (138, 1404)
# f:\Project\AMH/muldataset/00002-0427/face_landmarks.csv
# There are 13.0 faces recorded from this sample.
# (6084,)
# (468,)
# (139, 1404)
# f:\Project\AMH/muldataset/00002-0428/face_landmarks.csv
# There are 25.0 faces recorded from this sample.
# (11700,)
# (468,)
# (140, 1404)
# f:\Project\AMH/muldataset/00002-0429/face_landmarks.csv
# There are 50.0 faces recorded from this sample.
# (23400,)
# (468,)
# (141, 1404)
# f:\Project\AMH/muldataset/00002-0430/face_landmarks.csv
# There are 233.0 faces recorded from this sample.
# (109044,)
# (468,)
# (142, 1404)
# f:\Project\AMH/muldataset/00002-0431/face_landmarks.csv
# There are 199.0 faces recorded from this sample.
# (93132,)
# (468,)
# (143, 1404)
# f:\Project\AMH/muldataset/00002-0432/face_landmarks.csv
# There are 73.0 faces recorded from this sample.
# (34164,)
# (468,)
# (144, 1404)
# f:\Project\AMH/muldataset/00002-0433/face_landmarks.csv
# There are 57.0 faces recorded from this sample.
# (26676,)
# (468,)
# (145, 1404)
# f:\Project\AMH/muldataset/00002-0434/face_landmarks.csv
# There are 169.0 faces recorded from this sample.
# (79092,)
# (468,)
# (146, 1404)
# f:\Project\AMH/muldataset/00002-0437/face_landmarks.csv
# There are 106.0 faces recorded from this sample.
# (49608,)
# (468,)
# (147, 1404)
# f:\Project\AMH/muldataset/00002-0438/face_landmarks.csv
# There are 237.0 faces recorded from this sample.
# (110916,)
# (468,)
# (148, 1404)
# f:\Project\AMH/muldataset/00002-0439/face_landmarks.csv
# There are 216.0 faces recorded from this sample.
# (101088,)
# (468,)
# (149, 1404)
# f:\Project\AMH/muldataset/00002-0440/face_landmarks.csv
# There are 219.0 faces recorded from this sample.
# (102492,)
# (468,)
# (150, 1404)
# f:\Project\AMH/muldataset/00002-0441/face_landmarks.csv
# There are 223.0 faces recorded from this sample.
# (104364,)
# (468,)
# (151, 1404)
# f:\Project\AMH/muldataset/00002-0442/face_landmarks.csv
# There are 39.0 faces recorded from this sample.
# (18252,)
# (468,)
# (152, 1404)
# f:\Project\AMH/muldataset/00002-0501/face_landmarks.csv
# There are 166.0 faces recorded from this sample.
# (77688,)
# (468,)
# (153, 1404)
# f:\Project\AMH/muldataset/00002-0502/face_landmarks.csv
# There are 66.0 faces recorded from this sample.
# (30888,)
# (468,)
# (154, 1404)
# f:\Project\AMH/muldataset/00002-0503/face_landmarks.csv
# There are 29.0 faces recorded from this sample.
# (13572,)
# (468,)
# (155, 1404)
# f:\Project\AMH/muldataset/00002-0504/face_landmarks.csv
# There are 107.0 faces recorded from this sample.
# (50076,)
# (468,)
# (156, 1404)
# f:\Project\AMH/muldataset/00002-0505/face_landmarks.csv
# There are 164.0 faces recorded from this sample.
# (76752,)
# (468,)
# (157, 1404)
# f:\Project\AMH/muldataset/00002-0506/face_landmarks.csv
# There are 126.0 faces recorded from this sample.
# (58968,)
# (468,)
# (158, 1404)
# f:\Project\AMH/muldataset/00002-0507/face_landmarks.csv
# There are 164.0 faces recorded from this sample.
# (76752,)
# (468,)
# (159, 1404)
# f:\Project\AMH/muldataset/00002-0508/face_landmarks.csv
# There are 146.0 faces recorded from this sample.
# (68328,)
# (468,)
# (160, 1404)
# f:\Project\AMH/muldataset/00002-0509/face_landmarks.csv
# There are 13.0 faces recorded from this sample.
# (6084,)
# (468,)
# (161, 1404)
# f:\Project\AMH/muldataset/00002-0510/face_landmarks.csv
# There are 116.0 faces recorded from this sample.
# (54288,)
# (468,)
# (162, 1404)
# f:\Project\AMH/muldataset/00002-0511/face_landmarks.csv
# There are 62.0 faces recorded from this sample.
# (29016,)
# (468,)
# (163, 1404)
# f:\Project\AMH/muldataset/00002-0512/face_landmarks.csv
# There are 32.0 faces recorded from this sample.
# (14976,)
# (468,)
# (164, 1404)
# f:\Project\AMH/muldataset/00002-0513/face_landmarks.csv
# There are 51.0 faces recorded from this sample.
# (23868,)
# (468,)
# (165, 1404)
# f:\Project\AMH/muldataset/00002-0514/face_landmarks.csv
# There are 51.0 faces recorded from this sample.
# (23868,)
# (468,)
# (166, 1404)
# f:\Project\AMH/muldataset/00002-0515/face_landmarks.csv
# There are 33.0 faces recorded from this sample.
# (15444,)
# (468,)
# (167, 1404)
# f:\Project\AMH/muldataset/00002-0516/face_landmarks.csv
# There are 94.0 faces recorded from this sample.
# (43992,)
# (468,)
# (168, 1404)
# f:\Project\AMH/muldataset/00002-0517/face_landmarks.csv
# There are 16.0 faces recorded from this sample.
# (7488,)
# (468,)
# (169, 1404)
# f:\Project\AMH/muldataset/00002-0518/face_landmarks.csv
# There are 18.0 faces recorded from this sample.
# (8424,)
# (468,)
# (170, 1404)
# f:\Project\AMH/muldataset/00002-0519/face_landmarks.csv
# There are 136.0 faces recorded from this sample.
# (63648,)
# (468,)
# (171, 1404)
# f:\Project\AMH/muldataset/00002-0520/face_landmarks.csv
# There are 127.0 faces recorded from this sample.
# (59436,)
# (468,)
# (172, 1404)
# f:\Project\AMH/muldataset/00002-0521/face_landmarks.csv
# There are 106.0 faces recorded from this sample.
# (49608,)
# (468,)
# (173, 1404)
# f:\Project\AMH/muldataset/00002-0522/face_landmarks.csv
# There are 151.0 faces recorded from this sample.
# (70668,)
# (468,)
# (174, 1404)
# f:\Project\AMH/muldataset/00002-0523/face_landmarks.csv
# There are 37.0 faces recorded from this sample.
# (17316,)
# (468,)
# (175, 1404)
# f:\Project\AMH/muldataset/00002-0524/face_landmarks.csv
# There are 65.0 faces recorded from this sample.
# (30420,)
# (468,)
# (176, 1404)
# f:\Project\AMH/muldataset/00002-0526/face_landmarks.csv
# There are 268.0 faces recorded from this sample.
# (125424,)
# (468,)
# (177, 1404)
# f:\Project\AMH/muldataset/00002-0527/face_landmarks.csv
# There are 198.0 faces recorded from this sample.
# (92664,)
# (468,)
# (178, 1404)
# f:\Project\AMH/muldataset/00002-0528/face_landmarks.csv
# There are 74.0 faces recorded from this sample.
# (34632,)
# (468,)
# (179, 1404)
# f:\Project\AMH/muldataset/00002-0529/face_landmarks.csv
# There are 85.0 faces recorded from this sample.
# (39780,)
# (468,)
# (180, 1404)
# f:\Project\AMH/muldataset/00002-0530/face_landmarks.csv
# There are 236.0 faces recorded from this sample.
# (110448,)
# (468,)
# (181, 1404)
# f:\Project\AMH/muldataset/00002-0531/face_landmarks.csv
# There are 258.0 faces recorded from this sample.
# (120744,)
# (468,)
# (182, 1404)
# f:\Project\AMH/muldataset/00002-0532/face_landmarks.csv
# There are 213.0 faces recorded from this sample.
# (99684,)
# (468,)
# (183, 1404)
# f:\Project\AMH/muldataset/00002-0533/face_landmarks.csv
# There are 239.0 faces recorded from this sample.
# (111852,)
# (468,)
# (184, 1404)
# f:\Project\AMH/muldataset/00002-0601/face_landmarks.csv
# There are 85.0 faces recorded from this sample.
# (39780,)
# (468,)
# (185, 1404)
# f:\Project\AMH/muldataset/00002-0602/face_landmarks.csv
# There are 334.0 faces recorded from this sample.
# (156312,)
# (468,)
# (186, 1404)
# f:\Project\AMH/muldataset/00002-0603/face_landmarks.csv
# There are 196.0 faces recorded from this sample.
# (91728,)
# (468,)
# (187, 1404)
# f:\Project\AMH/muldataset/00002-0605/face_landmarks.csv
# There are 269.0 faces recorded from this sample.
# (125892,)
# (468,)
# (188, 1404)
# f:\Project\AMH/muldataset/00002-0606/face_landmarks.csv
# There are 230.0 faces recorded from this sample.
# (107640,)
# (468,)
# (189, 1404)
# f:\Project\AMH/muldataset/00002-0607/face_landmarks.csv
# There are 16.0 faces recorded from this sample.
# (7488,)
# (468,)
# (190, 1404)
# f:\Project\AMH/muldataset/00002-0609/face_landmarks.csv
# There are 151.0 faces recorded from this sample.
# (70668,)
# (468,)
# (191, 1404)
# f:\Project\AMH/muldataset/00002-0610/face_landmarks.csv
# There are 28.0 faces recorded from this sample.
# (13104,)
# (468,)
# (192, 1404)
# f:\Project\AMH/muldataset/00002-0611/face_landmarks.csv
# There are 68.0 faces recorded from this sample.
# (31824,)
# (468,)
# (193, 1404)
# f:\Project\AMH/muldataset/00002-0612/face_landmarks.csv
# There are 197.0 faces recorded from this sample.
# (92196,)
# (468,)
# (194, 1404)
# f:\Project\AMH/muldataset/00002-0613/face_landmarks.csv
# There are 266.0 faces recorded from this sample.
# (124488,)
# (468,)
# (195, 1404)
# f:\Project\AMH/muldataset/00002-0614/face_landmarks.csv
# There are 209.0 faces recorded from this sample.
# (97812,)
# (468,)
# (196, 1404)
# f:\Project\AMH/muldataset/00002-0615/face_landmarks.csv
# There are 107.0 faces recorded from this sample.
# (50076,)
# (468,)
# (197, 1404)
# f:\Project\AMH/muldataset/00002-0616/face_landmarks.csv
# There are 273.0 faces recorded from this sample.
# (127764,)
# (468,)
# (198, 1404)
# f:\Project\AMH/muldataset/00002-0618/face_landmarks.csv
# There are 53.0 faces recorded from this sample.
# (24804,)
# (468,)
# (199, 1404)
# f:\Project\AMH/muldataset/00002-0619/face_landmarks.csv
# There are 683.0 faces recorded from this sample.
# (319644,)
# (468,)
# (200, 1404)
# f:\Project\AMH/muldataset/00002-0620/face_landmarks.csv
# There are 250.0 faces recorded from this sample.
# (117000,)
# (468,)
# (201, 1404)
# f:\Project\AMH/muldataset/00002-0621/face_landmarks.csv
# There are 192.0 faces recorded from this sample.
# (89856,)
# (468,)
# (202, 1404)
# f:\Project\AMH/muldataset/00002-0623/face_landmarks.csv
# There are 164.0 faces recorded from this sample.
# (76752,)
# (468,)
# (203, 1404)
# f:\Project\AMH/muldataset/00002-0624/face_landmarks.csv
# There are 158.0 faces recorded from this sample.
# (73944,)
# (468,)
# (204, 1404)
# f:\Project\AMH/muldataset/00002-0626/face_landmarks.csv
# There are 240.0 faces recorded from this sample.
# (112320,)
# (468,)
# (205, 1404)
# f:\Project\AMH/muldataset/00002-0627/face_landmarks.csv
# There are 52.0 faces recorded from this sample.
# (24336,)
# (468,)
# (206, 1404)
# f:\Project\AMH/muldataset/00002-0628/face_landmarks.csv
# There are 237.0 faces recorded from this sample.
# (110916,)
# (468,)
# (207, 1404)
# f:\Project\AMH/muldataset/00002-0630/face_landmarks.csv
# There are 196.0 faces recorded from this sample.
# (91728,)
# (468,)
# (208, 1404)
# f:\Project\AMH/muldataset/00002-0631/face_landmarks.csv
# There are 131.0 faces recorded from this sample.
# (61308,)
# (468,)
# (209, 1404)
# f:\Project\AMH/muldataset/00002-0633/face_landmarks.csv
# There are 150.0 faces recorded from this sample.
# (70200,)
# (468,)
# (210, 1404)
# f:\Project\AMH/muldataset/00002-0634/face_landmarks.csv
# There are 222.0 faces recorded from this sample.
# (103896,)
# (468,)
# (211, 1404)
# f:\Project\AMH/muldataset/00002-0701/face_landmarks.csv
# There are 217.0 faces recorded from this sample.
# (101556,)
# (468,)
# (212, 1404)
# f:\Project\AMH/muldataset/00002-0702/face_landmarks.csv
# There are 101.0 faces recorded from this sample.
# (47268,)
# (468,)
# (213, 1404)
# f:\Project\AMH/muldataset/00002-0703/face_landmarks.csv
# There are 170.0 faces recorded from this sample.
# (79560,)
# (468,)
# (214, 1404)
# f:\Project\AMH/muldataset/00002-0704/face_landmarks.csv
# There are 88.0 faces recorded from this sample.
# (41184,)
# (468,)
# (215, 1404)
# f:\Project\AMH/muldataset/00002-0705/face_landmarks.csv
# There are 141.0 faces recorded from this sample.
# (65988,)
# (468,)
# (216, 1404)
# f:\Project\AMH/muldataset/00002-0706/face_landmarks.csv
# There are 32.0 faces recorded from this sample.
# (14976,)
# (468,)
# (217, 1404)
# f:\Project\AMH/muldataset/00002-0707/face_landmarks.csv
# There are 117.0 faces recorded from this sample.
# (54756,)
# (468,)
# (218, 1404)
# f:\Project\AMH/muldataset/00002-0708/face_landmarks.csv
# There are 245.0 faces recorded from this sample.
# (114660,)
# (468,)
# (219, 1404)
# f:\Project\AMH/muldataset/00002-0709/face_landmarks.csv
# There are 242.0 faces recorded from this sample.
# (113256,)
# (468,)
# (220, 1404)
# f:\Project\AMH/muldataset/00002-0710/face_landmarks.csv
# There are 18.0 faces recorded from this sample.
# (8424,)
# (468,)
# (221, 1404)
# f:\Project\AMH/muldataset/00002-0711/face_landmarks.csv
# There are 173.0 faces recorded from this sample.
# (80964,)
# (468,)
# (222, 1404)
# f:\Project\AMH/muldataset/00002-0712/face_landmarks.csv
# There are 115.0 faces recorded from this sample.
# (53820,)
# (468,)
# (223, 1404)
# f:\Project\AMH/muldataset/00002-0713/face_landmarks.csv
# There are 215.0 faces recorded from this sample.
# (100620,)
# (468,)
# (224, 1404)
# f:\Project\AMH/muldataset/00002-0714/face_landmarks.csv
# There are 223.0 faces recorded from this sample.
# (104364,)
# (468,)
# (225, 1404)
# f:\Project\AMH/muldataset/00002-0715/face_landmarks.csv
# There are 228.0 faces recorded from this sample.
# (106704,)
# (468,)
# (226, 1404)
# f:\Project\AMH/muldataset/00002-0716/face_landmarks.csv
# There are 203.0 faces recorded from this sample.
# (95004,)
# (468,)
# (227, 1404)
# f:\Project\AMH/muldataset/00002-0717/face_landmarks.csv
# There are 235.0 faces recorded from this sample.
# (109980,)
# (468,)
# (228, 1404)
# f:\Project\AMH/muldataset/00002-0718/face_landmarks.csv
# There are 108.0 faces recorded from this sample.
# (50544,)
# (468,)
# (229, 1404)
# f:\Project\AMH/muldataset/00002-0719/face_landmarks.csv
# There are 86.0 faces recorded from this sample.
# (40248,)
# (468,)
# (230, 1404)
# f:\Project\AMH/muldataset/00002-0720/face_landmarks.csv
# There are 46.0 faces recorded from this sample.
# (21528,)
# (468,)
# (231, 1404)
# f:\Project\AMH/muldataset/00002-0721/face_landmarks.csv
# There are 107.0 faces recorded from this sample.
# (50076,)
# (468,)
# (232, 1404)
# f:\Project\AMH/muldataset/00002-0722/face_landmarks.csv
# There are 137.0 faces recorded from this sample.
# (64116,)
# (468,)
# (233, 1404)
# f:\Project\AMH/muldataset/00002-0724/face_landmarks.csv
# There are 241.0 faces recorded from this sample.
# (112788,)
# (468,)
# (234, 1404)
# f:\Project\AMH/muldataset/00002-0725/face_landmarks.csv
# There are 67.0 faces recorded from this sample.
# (31356,)
# (468,)
# (235, 1404)
# f:\Project\AMH/muldataset/00002-0726/face_landmarks.csv
# There are 75.0 faces recorded from this sample.
# (35100,)
# (468,)
# (236, 1404)
# f:\Project\AMH/muldataset/00002-0727/face_landmarks.csv
# There are 62.0 faces recorded from this sample.
# (29016,)
# (468,)
# (237, 1404)
# f:\Project\AMH/muldataset/00002-0728/face_landmarks.csv
# There are 151.0 faces recorded from this sample.
# (70668,)
# (468,)
# (238, 1404)
# f:\Project\AMH/muldataset/00002-0729/face_landmarks.csv
# There are 21.0 faces recorded from this sample.
# (9828,)
# (468,)
# (239, 1404)
# f:\Project\AMH/muldataset/00002-0730/face_landmarks.csv
# There are 151.0 faces recorded from this sample.
# (70668,)
# (468,)
# (240, 1404)
# f:\Project\AMH/muldataset/00002-0731/face_landmarks.csv
# There are 17.0 faces recorded from this sample.
# (7956,)
# (468,)
# (241, 1404)
# f:\Project\AMH/muldataset/00002-0732/face_landmarks.csv
# There are 156.0 faces recorded from this sample.
# (73008,)
# (468,)
# (242, 1404)
# f:\Project\AMH/muldataset/00002-0801/face_landmarks.csv
# There are 198.0 faces recorded from this sample.
# (92664,)
# (468,)
# (243, 1404)
# f:\Project\AMH/muldataset/00002-0802/face_landmarks.csv
# There are 50.0 faces recorded from this sample.
# (23400,)
# (468,)
# (244, 1404)
# f:\Project\AMH/muldataset/00002-0803/face_landmarks.csv
# There are 17.0 faces recorded from this sample.
# (7956,)
# (468,)
# (245, 1404)
# f:\Project\AMH/muldataset/00002-0804/face_landmarks.csv
# There are 163.0 faces recorded from this sample.
# (76284,)
# (468,)
# (246, 1404)
# f:\Project\AMH/muldataset/00002-0805/face_landmarks.csv
# There are 113.0 faces recorded from this sample.
# (52884,)
# (468,)
# (247, 1404)
# f:\Project\AMH/muldataset/00002-0806/face_landmarks.csv
# There are 129.0 faces recorded from this sample.
# (60372,)
# (468,)
# (248, 1404)
# f:\Project\AMH/muldataset/00002-0807/face_landmarks.csv
# There are 99.0 faces recorded from this sample.
# (46332,)
# (468,)
# (249, 1404)
# f:\Project\AMH/muldataset/00002-0808/face_landmarks.csv
# There are 210.0 faces recorded from this sample.
# (98280,)
# (468,)
# (250, 1404)
# f:\Project\AMH/muldataset/00002-0809/face_landmarks.csv
# There are 179.0 faces recorded from this sample.
# (83772,)
# (468,)
# (251, 1404)
# f:\Project\AMH/muldataset/00002-0810/face_landmarks.csv
# There are 135.0 faces recorded from this sample.
# (63180,)
# (468,)
# (252, 1404)
# f:\Project\AMH/muldataset/00002-0811/face_landmarks.csv
# There are 199.0 faces recorded from this sample.
# (93132,)
# (468,)
# (253, 1404)
# f:\Project\AMH/muldataset/00002-0812/face_landmarks.csv
# There are 228.0 faces recorded from this sample.
# (106704,)
# (468,)
# (254, 1404)
# f:\Project\AMH/muldataset/00002-0813/face_landmarks.csv
# There are 242.0 faces recorded from this sample.
# (113256,)
# (468,)
# (255, 1404)
# f:\Project\AMH/muldataset/00002-0814/face_landmarks.csv
# There are 250.0 faces recorded from this sample.
# (117000,)
# (468,)
# (256, 1404)
# f:\Project\AMH/muldataset/00002-0815/face_landmarks.csv
# There are 257.0 faces recorded from this sample.
# (120276,)
# (468,)
# (257, 1404)
# f:\Project\AMH/muldataset/00002-0817/face_landmarks.csv
# There are 248.0 faces recorded from this sample.
# (116064,)
# (468,)
# (258, 1404)
# f:\Project\AMH/muldataset/00002-0818/face_landmarks.csv
# There are 248.0 faces recorded from this sample.
# (116064,)
# (468,)
# (259, 1404)
# f:\Project\AMH/muldataset/00002-0819/face_landmarks.csv
# There are 246.0 faces recorded from this sample.
# (115128,)
# (468,)
# (260, 1404)
# f:\Project\AMH/muldataset/00002-0820/face_landmarks.csv
# There are 48.0 faces recorded from this sample.
# (22464,)
# (468,)
# (261, 1404)
# f:\Project\AMH/muldataset/00002-0821/face_landmarks.csv
# There are 46.0 faces recorded from this sample.
# (21528,)
# (468,)
# (262, 1404)
# f:\Project\AMH/muldataset/00002-0822/face_landmarks.csv
# There are 71.0 faces recorded from this sample.
# (33228,)
# (468,)
# (263, 1404)
# f:\Project\AMH/muldataset/00002-0823/face_landmarks.csv
# There are 252.0 faces recorded from this sample.
# (117936,)
# (468,)
# (264, 1404)
# f:\Project\AMH/muldataset/00002-0824/face_landmarks.csv
# There are 186.0 faces recorded from this sample.
# (87048,)
# (468,)
# (265, 1404)
# f:\Project\AMH/muldataset/00002-0825/face_landmarks.csv
# There are 179.0 faces recorded from this sample.
# (83772,)
# (468,)
# (266, 1404)
# f:\Project\AMH/muldataset/00002-0826/face_landmarks.csv
# There are 133.0 faces recorded from this sample.
# (62244,)
# (468,)
# (267, 1404)
# f:\Project\AMH/muldataset/00002-0827/face_landmarks.csv
# There are 118.0 faces recorded from this sample.
# (55224,)
# (468,)
# (268, 1404)
# f:\Project\AMH/muldataset/00002-0829/face_landmarks.csv
# There are 61.0 faces recorded from this sample.
# (28548,)
# (468,)
# (269, 1404)
# f:\Project\AMH/muldataset/00002-0832/face_landmarks.csv
# There are 208.0 faces recorded from this sample.
# (97344,)
# (468,)
# (270, 1404)
# f:\Project\AMH/muldataset/00002-0901/face_landmarks.csv
# There are 152.0 faces recorded from this sample.
# (71136,)
# (468,)
# (271, 1404)
# f:\Project\AMH/muldataset/00002-0904/face_landmarks.csv
# There are 153.0 faces recorded from this sample.
# (71604,)
# (468,)
# (272, 1404)
# f:\Project\AMH/muldataset/00002-0905/face_landmarks.csv
# There are 335.0 faces recorded from this sample.
# (156780,)
# (468,)
# (273, 1404)
# f:\Project\AMH/muldataset/00002-0908/face_landmarks.csv
# There are 136.0 faces recorded from this sample.
# (63648,)
# (468,)
# (274, 1404)
# f:\Project\AMH/muldataset/00002-0909/face_landmarks.csv
# There are 65.0 faces recorded from this sample.
# (30420,)
# (468,)
# (275, 1404)
# f:\Project\AMH/muldataset/00002-0910/face_landmarks.csv
# There are 54.0 faces recorded from this sample.
# (25272,)
# (468,)
# (276, 1404)
# f:\Project\AMH/muldataset/00002-0911/face_landmarks.csv
# There are 13.0 faces recorded from this sample.
# (6084,)
# (468,)
# (277, 1404)
# f:\Project\AMH/muldataset/00002-0912/face_landmarks.csv
# There are 85.0 faces recorded from this sample.
# (39780,)
# (468,)
# (278, 1404)
# f:\Project\AMH/muldataset/00002-0913/face_landmarks.csv
# There are 158.0 faces recorded from this sample.
# (73944,)
# (468,)
# (279, 1404)
# f:\Project\AMH/muldataset/00002-0915/face_landmarks.csv
# There are 156.0 faces recorded from this sample.
# (73008,)
# (468,)
# (280, 1404)
# f:\Project\AMH/muldataset/00002-0916/face_landmarks.csv
# There are 142.0 faces recorded from this sample.
# (66456,)
# (468,)
# (281, 1404)
# f:\Project\AMH/muldataset/00002-0917/face_landmarks.csv
# There are 145.0 faces recorded from this sample.
# (67860,)
# (468,)
# (282, 1404)
# f:\Project\AMH/muldataset/00002-0919/face_landmarks.csv
# There are 155.0 faces recorded from this sample.
# (72540,)
# (468,)
# (283, 1404)
# f:\Project\AMH/muldataset/00002-0920/face_landmarks.csv
# There are 69.0 faces recorded from this sample.
# (32292,)
# (468,)
# (284, 1404)
# f:\Project\AMH/muldataset/00002-0921/face_landmarks.csv
# There are 153.0 faces recorded from this sample.
# (71604,)
# (468,)
# (285, 1404)
# f:\Project\AMH/muldataset/00002-0922/face_landmarks.csv
# There are 104.0 faces recorded from this sample.
# (48672,)
# (468,)
# (286, 1404)
# f:\Project\AMH/muldataset/00002-0923/face_landmarks.csv
# There are 198.0 faces recorded from this sample.
# (92664,)
# (468,)
# (287, 1404)
# f:\Project\AMH/muldataset/00002-0924/face_landmarks.csv
# There are 182.0 faces recorded from this sample.
# (85176,)
# (468,)
# (288, 1404)
# f:\Project\AMH/muldataset/00002-0925/face_landmarks.csv
# There are 86.0 faces recorded from this sample.
# (40248,)
# (468,)
# (289, 1404)
# f:\Project\AMH/muldataset/00002-0926/face_landmarks.csv
# There are 123.0 faces recorded from this sample.
# (57564,)
# (468,)
# (290, 1404)
# f:\Project\AMH/muldataset/00002-0927/face_landmarks.csv
# There are 159.0 faces recorded from this sample.
# (74412,)
# (468,)
# (291, 1404)
# f:\Project\AMH/muldataset/00002-0928/face_landmarks.csv
# There are 105.0 faces recorded from this sample.
# (49140,)
# (468,)
# (292, 1404)
# f:\Project\AMH/muldataset/00002-0929/face_landmarks.csv
# There are 137.0 faces recorded from this sample.
# (64116,)
# (468,)
# (293, 1404)
# f:\Project\AMH/muldataset/00002-0930/face_landmarks.csv
# There are 94.0 faces recorded from this sample.
# (43992,)
# (468,)
# (294, 1404)
# f:\Project\AMH/muldataset/00002-0931/face_landmarks.csv
# There are 149.0 faces recorded from this sample.
# (69732,)
# (468,)
# (295, 1404)
# f:\Project\AMH/muldataset/00002-0932/face_landmarks.csv
# There are 88.0 faces recorded from this sample.
# (41184,)
# (468,)
# (296, 1404)
# f:\Project\AMH/muldataset/00002-1001/face_landmarks.csv
# There are 79.0 faces recorded from this sample.
# (36972,)
# (468,)
# (297, 1404)
# f:\Project\AMH/muldataset/00002-1002/face_landmarks.csv
# There are 174.0 faces recorded from this sample.
# (81432,)
# (468,)
# (298, 1404)
# f:\Project\AMH/muldataset/00002-1004/face_landmarks.csv
# There are 79.0 faces recorded from this sample.
# (36972,)
# (468,)
# (299, 1404)
# f:\Project\AMH/muldataset/00002-1005/face_landmarks.csv
# There are 388.0 faces recorded from this sample.
# (181584,)
# (468,)
# (300, 1404)
# f:\Project\AMH/muldataset/00002-1006/face_landmarks.csv
# There are 273.0 faces recorded from this sample.
# (127764,)
# (468,)
# (301, 1404)
# f:\Project\AMH/muldataset/00002-1007/face_landmarks.csv
# There are 224.0 faces recorded from this sample.
# (104832,)
# (468,)
# (302, 1404)
# f:\Project\AMH/muldataset/00002-1008/face_landmarks.csv
# There are 186.0 faces recorded from this sample.
# (87048,)
# (468,)
# (303, 1404)
# f:\Project\AMH/muldataset/00002-1009/face_landmarks.csv
# There are 166.0 faces recorded from this sample.
# (77688,)
# (468,)
# (304, 1404)
# f:\Project\AMH/muldataset/00002-1010/face_landmarks.csv
# There are 166.0 faces recorded from this sample.
# (77688,)
# (468,)
# (305, 1404)
# f:\Project\AMH/muldataset/00002-1011/face_landmarks.csv
# There are 258.0 faces recorded from this sample.
# (120744,)
# (468,)
# (306, 1404)
# f:\Project\AMH/muldataset/00002-1013/face_landmarks.csv
# There are 135.0 faces recorded from this sample.
# (63180,)
# (468,)
# (307, 1404)
# f:\Project\AMH/muldataset/00002-1015/face_landmarks.csv
# There are 227.0 faces recorded from this sample.
# (106236,)
# (468,)
# (308, 1404)
# f:\Project\AMH/muldataset/00002-1017/face_landmarks.csv
# There are 67.0 faces recorded from this sample.
# (31356,)
# (468,)
# (309, 1404)
# f:\Project\AMH/muldataset/00002-1019/face_landmarks.csv
# There are 248.0 faces recorded from this sample.
# (116064,)
# (468,)
# (310, 1404)
# f:\Project\AMH/muldataset/00002-1021/face_landmarks.csv
# There are 167.0 faces recorded from this sample.
# (78156,)
# (468,)
# (311, 1404)
# f:\Project\AMH/muldataset/00002-1022/face_landmarks.csv
# There are 205.0 faces recorded from this sample.
# (95940,)
# (468,)
# (312, 1404)
# f:\Project\AMH/muldataset/00002-1023/face_landmarks.csv
# There are 145.0 faces recorded from this sample.
# (67860,)
# (468,)
# (313, 1404)
# f:\Project\AMH/muldataset/00002-1024/face_landmarks.csv
# There are 238.0 faces recorded from this sample.
# (111384,)
# (468,)
# (314, 1404)
# f:\Project\AMH/muldataset/00002-1025/face_landmarks.csv
# There are 216.0 faces recorded from this sample.
# (101088,)
# (468,)
# (315, 1404)
# f:\Project\AMH/muldataset/00002-1027/face_landmarks.csv
# There are 224.0 faces recorded from this sample.
# (104832,)
# (468,)
# (316, 1404)
# f:\Project\AMH/muldataset/00002-1028/face_landmarks.csv
# There are 156.0 faces recorded from this sample.
# (73008,)
# (468,)
# (317, 1404)
# f:\Project\AMH/muldataset/00002-1029/face_landmarks.csv
# There are 189.0 faces recorded from this sample.
# (88452,)
# (468,)
# (318, 1404)
# f:\Project\AMH/muldataset/00002-1030/face_landmarks.csv
# There are 125.0 faces recorded from this sample.
# (58500,)
# (468,)
# (319, 1404)
# f:\Project\AMH/muldataset/00002-1031/face_landmarks.csv
# There are 241.0 faces recorded from this sample.
# (112788,)
# (468,)
# (320, 1404)
# f:\Project\AMH/muldataset/00002-1032/face_landmarks.csv
# There are 233.0 faces recorded from this sample.
# (109044,)
# (468,)
# (321, 1404)
# f:\Project\AMH/muldataset/00002-1033/face_landmarks.csv
# There are 216.0 faces recorded from this sample.
# (101088,)
# (468,)
# (322, 1404)
# f:\Project\AMH/muldataset/00002-1034/face_landmarks.csv
# There are 165.0 faces recorded from this sample.
# (77220,)
# (468,)
# (323, 1404)
# f:\Project\AMH/muldataset/00002-1101/face_landmarks.csv
# There are 58.0 faces recorded from this sample.
# (27144,)
# (468,)
# (324, 1404)
# f:\Project\AMH/muldataset/00002-1102/face_landmarks.csv
# There are 229.0 faces recorded from this sample.
# (107172,)
# (468,)
# (325, 1404)
# f:\Project\AMH/muldataset/00002-1104/face_landmarks.csv
# There are 247.0 faces recorded from this sample.
# (115596,)
# (468,)
# (326, 1404)
# f:\Project\AMH/muldataset/00002-1106/face_landmarks.csv
# There are 74.0 faces recorded from this sample.
# (34632,)
# (468,)
# (327, 1404)
# f:\Project\AMH/muldataset/00002-1107/face_landmarks.csv
# There are 250.0 faces recorded from this sample.
# (117000,)
# (468,)
# (328, 1404)
# f:\Project\AMH/muldataset/00002-1108/face_landmarks.csv
# There are 228.0 faces recorded from this sample.
# (106704,)
# (468,)
# (329, 1404)
# f:\Project\AMH/muldataset/00002-1109/face_landmarks.csv
# There are 150.0 faces recorded from this sample.
# (70200,)
# (468,)
# (330, 1404)
# f:\Project\AMH/muldataset/00002-1110/face_landmarks.csv
# There are 89.0 faces recorded from this sample.
# (41652,)
# (468,)
# (331, 1404)
# f:\Project\AMH/muldataset/00002-1111/face_landmarks.csv
# There are 169.0 faces recorded from this sample.
# (79092,)
# (468,)
# (332, 1404)
# f:\Project\AMH/muldataset/00002-1112/face_landmarks.csv
# There are 164.0 faces recorded from this sample.
# (76752,)
# (468,)
# (333, 1404)
# f:\Project\AMH/muldataset/00002-1113/face_landmarks.csv
# There are 256.0 faces recorded from this sample.
# (119808,)
# (468,)
# (334, 1404)
# f:\Project\AMH/muldataset/00002-1115/face_landmarks.csv
# There are 182.0 faces recorded from this sample.
# (85176,)
# (468,)
# (335, 1404)
# f:\Project\AMH/muldataset/00002-1116/face_landmarks.csv
# There are 249.0 faces recorded from this sample.
# (116532,)
# (468,)
# (336, 1404)
# f:\Project\AMH/muldataset/00002-1117/face_landmarks.csv
# There are 177.0 faces recorded from this sample.
# (82836,)
# (468,)
# (337, 1404)
# f:\Project\AMH/muldataset/00002-1118/face_landmarks.csv
# There are 102.0 faces recorded from this sample.
# (47736,)
# (468,)
# (338, 1404)
# f:\Project\AMH/muldataset/00002-1119/face_landmarks.csv
# There are 142.0 faces recorded from this sample.
# (66456,)
# (468,)
# (339, 1404)
# f:\Project\AMH/muldataset/00002-1120/face_landmarks.csv
# There are 273.0 faces recorded from this sample.
# (127764,)
# (468,)
# (340, 1404)
# f:\Project\AMH/muldataset/00002-1121/face_landmarks.csv
# There are 44.0 faces recorded from this sample.
# (20592,)
# (468,)
# (341, 1404)
# f:\Project\AMH/muldataset/00002-1122/face_landmarks.csv
# There are 66.0 faces recorded from this sample.
# (30888,)
# (468,)
# (342, 1404)
# f:\Project\AMH/muldataset/00002-1123/face_landmarks.csv
# There are 251.0 faces recorded from this sample.
# (117468,)
# (468,)
# (343, 1404)
# f:\Project\AMH/muldataset/00002-1124/face_landmarks.csv
# There are 254.0 faces recorded from this sample.
# (118872,)
# (468,)
# (344, 1404)
# f:\Project\AMH/muldataset/00002-1125/face_landmarks.csv
# There are 88.0 faces recorded from this sample.
# (41184,)
# (468,)
# (345, 1404)
# f:\Project\AMH/muldataset/00002-1126/face_landmarks.csv
# There are 218.0 faces recorded from this sample.
# (102024,)
# (468,)
# (346, 1404)
# f:\Project\AMH/muldataset/00002-1127/face_landmarks.csv
# There are 191.0 faces recorded from this sample.
# (89388,)
# (468,)
# (347, 1404)
# f:\Project\AMH/muldataset/00002-1128/face_landmarks.csv
# There are 160.0 faces recorded from this sample.
# (74880,)
# (468,)
# (348, 1404)
# f:\Project\AMH/muldataset/00002-1129/face_landmarks.csv
# There are 194.0 faces recorded from this sample.
# (90792,)
# (468,)
# (349, 1404)
# f:\Project\AMH/muldataset/00002-1130/face_landmarks.csv
# There are 258.0 faces recorded from this sample.
# (120744,)
# (468,)
# (350, 1404)
# f:\Project\AMH/muldataset/00002-1131/face_landmarks.csv
# There are 94.0 faces recorded from this sample.
# (43992,)
# (468,)
# (351, 1404)
# f:\Project\AMH/muldataset/00002-1132/face_landmarks.csv
# There are 255.0 faces recorded from this sample.
# (119340,)
# (468,)
# (352, 1404)
# f:\Project\AMH/muldataset/00002-1135/face_landmarks.csv
# There are 110.0 faces recorded from this sample.
# (51480,)
# (468,)
# (353, 1404)
# f:\Project\AMH/muldataset/00002-1201/face_landmarks.csv
# There are 216.0 faces recorded from this sample.
# (101088,)
# (468,)
# (354, 1404)
# f:\Project\AMH/muldataset/00002-1202/face_landmarks.csv
# There are 111.0 faces recorded from this sample.
# (51948,)
# (468,)
# (355, 1404)
# f:\Project\AMH/muldataset/00002-1204/face_landmarks.csv
# There are 247.0 faces recorded from this sample.
# (115596,)
# (468,)
# (356, 1404)
# f:\Project\AMH/muldataset/00002-1205/face_landmarks.csv
# There are 172.0 faces recorded from this sample.
# (80496,)
# (468,)
# (357, 1404)
# f:\Project\AMH/muldataset/00002-1206/face_landmarks.csv
# There are 39.0 faces recorded from this sample.
# (18252,)
# (468,)
# (358, 1404)
# f:\Project\AMH/muldataset/00002-1207/face_landmarks.csv
# There are 20.0 faces recorded from this sample.
# (9360,)
# (468,)
# (359, 1404)
# f:\Project\AMH/muldataset/00002-1208/face_landmarks.csv
# There are 137.0 faces recorded from this sample.
# (64116,)
# (468,)
# (360, 1404)
# f:\Project\AMH/muldataset/00002-1209/face_landmarks.csv
# There are 216.0 faces recorded from this sample.
# (101088,)
# (468,)
# (361, 1404)
# ...
# There are 188.0 faces recorded from this sample.
# (87984,)
# (468,)
# (988, 1404)
# f:\Project\AMH/muldataset/00004-2132/face_landmarks.csv
# There are 163.0 faces recorded from this sample.
# (76284,)
# (468,)
# (989, 1404)
# f:\Project\AMH/muldataset/00004-2133/face_landmarks.csv
# There are 220.0 faces recorded from this sample.
# (102960,)
# (468,)
# (990, 1404)
# f:\Project\AMH/muldataset/00004-2135/face_landmarks.csv
# There are 13.0 faces recorded from this sample.
# (6084,)
# (468,)
# (991, 1404)
# f:\Project\AMH/muldataset/00004-2138/face_landmarks.csv
# There are 162.0 faces recorded from this sample.
# (75816,)
# (468,)
# (992, 1404)
# f:\Project\AMH/muldataset/00004-2139/face_landmarks.csv
# There are 21.0 faces recorded from this sample.
# (9828,)
# (468,)
# (993, 1404)
# f:\Project\AMH/muldataset/00004-2140/face_landmarks.csv
# There are 17.0 faces recorded from this sample.
# (7956,)
# (468,)
# (994, 1404)
# f:\Project\AMH/muldataset/00004-2141/face_landmarks.csv
# There are 167.0 faces recorded from this sample.
# (78156,)
# (468,)
# (995, 1404)
# f:\Project\AMH/muldataset/00004-2142/face_landmarks.csv
# There are 49.0 faces recorded from this sample.
# (22932,)
# (468,)
# (996, 1404)
# f:\Project\AMH/muldataset/00004-2143/face_landmarks.csv
# There are 133.0 faces recorded from this sample.
# (62244,)
# (468,)
# (997, 1404)
# f:\Project\AMH/muldataset/00004-2144/face_landmarks.csv
# There are 224.0 faces recorded from this sample.
# (104832,)
# (468,)
# (998, 1404)
# f:\Project\AMH/muldataset/00004-2145/face_landmarks.csv
# There are 61.0 faces recorded from this sample.
# (28548,)
# (468,)
# (999, 1404)
# f:\Project\AMH/muldataset/00004-2146/face_landmarks.csv
# There are 173.0 faces recorded from this sample.
# (80964,)
# (468,)
# (1000, 1404)
# f:\Project\AMH/muldataset/00004-2149/face_landmarks.csv
# There are 181.0 faces recorded from this sample.
# (84708,)
# (468,)
# (1001, 1404)
# f:\Project\AMH/muldataset/00004-2201/face_landmarks.csv
# There are 28.0 faces recorded from this sample.
# (13104,)
# (468,)
# (1002, 1404)
# f:\Project\AMH/muldataset/00004-2202/face_landmarks.csv
# There are 15.0 faces recorded from this sample.
# (7020,)
# (468,)
# (1003, 1404)
# f:\Project\AMH/muldataset/00004-2204/face_landmarks.csv
# There are 124.0 faces recorded from this sample.
# (58032,)
# (468,)
# (1004, 1404)
# f:\Project\AMH/muldataset/00004-2205/face_landmarks.csv
# There are 24.0 faces recorded from this sample.
# (11232,)
# (468,)
# (1005, 1404)
# f:\Project\AMH/muldataset/00004-2206/face_landmarks.csv
# There are 25.0 faces recorded from this sample.
# (11700,)
# (468,)
# (1006, 1404)
# f:\Project\AMH/muldataset/00004-2208/face_landmarks.csv
# There are 302.0 faces recorded from this sample.
# (141336,)
# (468,)
# (1007, 1404)
# f:\Project\AMH/muldataset/00004-2210/face_landmarks.csv
# There are 155.0 faces recorded from this sample.
# (72540,)
# (468,)
# (1008, 1404)
# f:\Project\AMH/muldataset/00004-2212/face_landmarks.csv
# There are 63.0 faces recorded from this sample.
# (29484,)
# (468,)
# (1009, 1404)
# f:\Project\AMH/muldataset/00004-2213/face_landmarks.csv
# There are 77.0 faces recorded from this sample.
# (36036,)
# (468,)
# (1010, 1404)
# f:\Project\AMH/muldataset/00004-2214/face_landmarks.csv
# There are 38.0 faces recorded from this sample.
# (17784,)
# (468,)
# (1011, 1404)
# f:\Project\AMH/muldataset/00004-2215/face_landmarks.csv
# There are 167.0 faces recorded from this sample.
# (78156,)
# (468,)
# (1012, 1404)
# f:\Project\AMH/muldataset/00004-2216/face_landmarks.csv
# There are 39.0 faces recorded from this sample.
# (18252,)
# (468,)
# (1013, 1404)
# f:\Project\AMH/muldataset/00004-2217/face_landmarks.csv
# There are 132.0 faces recorded from this sample.
# (61776,)
# (468,)
# (1014, 1404)
# f:\Project\AMH/muldataset/00004-2218/face_landmarks.csv
# There are 130.0 faces recorded from this sample.
# (60840,)
# (468,)
# (1015, 1404)
# f:\Project\AMH/muldataset/00004-2219/face_landmarks.csv
# There are 30.0 faces recorded from this sample.
# (14040,)
# (468,)
# (1016, 1404)
# f:\Project\AMH/muldataset/00004-2220/face_landmarks.csv
# There are 95.0 faces recorded from this sample.
# (44460,)
# (468,)
# (1017, 1404)
# f:\Project\AMH/muldataset/00004-2221/face_landmarks.csv
# There are 15.0 faces recorded from this sample.
# (7020,)
# (468,)
# (1018, 1404)
# f:\Project\AMH/muldataset/00004-2222/face_landmarks.csv
# There are 128.0 faces recorded from this sample.
# (59904,)
# (468,)
# (1019, 1404)
# f:\Project\AMH/muldataset/00004-2223/face_landmarks.csv
# There are 161.0 faces recorded from this sample.
# (75348,)
# (468,)
# (1020, 1404)
# f:\Project\AMH/muldataset/00004-2224/face_landmarks.csv
# There are 143.0 faces recorded from this sample.
# (66924,)
# (468,)
# (1021, 1404)
# f:\Project\AMH/muldataset/00004-2225/face_landmarks.csv
# There are 201.0 faces recorded from this sample.
# (94068,)
# (468,)
# (1022, 1404)
# f:\Project\AMH/muldataset/00004-2226/face_landmarks.csv
# There are 122.0 faces recorded from this sample.
# (57096,)
# (468,)
# (1023, 1404)
# f:\Project\AMH/muldataset/00004-2227/face_landmarks.csv
# There are 159.0 faces recorded from this sample.
# (74412,)
# (468,)
# (1024, 1404)
# f:\Project\AMH/muldataset/00004-2228/face_landmarks.csv
# There are 260.0 faces recorded from this sample.
# (121680,)
# (468,)
# (1025, 1404)
# f:\Project\AMH/muldataset/00004-2229/face_landmarks.csv
# There are 24.0 faces recorded from this sample.
# (11232,)
# (468,)
# (1026, 1404)
# f:\Project\AMH/muldataset/00004-2230/face_landmarks.csv
# There are 45.0 faces recorded from this sample.
# (21060,)
# (468,)
# (1027, 1404)
# f:\Project\AMH/muldataset/00004-2231/face_landmarks.csv
# There are 63.0 faces recorded from this sample.
# (29484,)
# (468,)
# (1028, 1404)
# f:\Project\AMH/muldataset/00004-2232/face_landmarks.csv
# There are 111.0 faces recorded from this sample.
# (51948,)
# (468,)
# (1029, 1404)
# f:\Project\AMH/muldataset/00004-2235/face_landmarks.csv
# There are 114.0 faces recorded from this sample.
# (53352,)
# (468,)
# (1030, 1404)
# f:\Project\AMH/muldataset/00004-2236/face_landmarks.csv
# There are 373.0 faces recorded from this sample.
# (174564,)
# (468,)
# (1031, 1404)
# f:\Project\AMH/muldataset/00004-2237/face_landmarks.csv
# There are 62.0 faces recorded from this sample.
# (29016,)
# (468,)
# (1032, 1404)
# f:\Project\AMH/muldataset/00004-2238/face_landmarks.csv
# There are 65.0 faces recorded from this sample.
# (30420,)
# (468,)
# (1033, 1404)
# f:\Project\AMH/muldataset/00004-2241/face_landmarks.csv
# There are 23.0 faces recorded from this sample.
# (10764,)
# (468,)
# (1034, 1404)
# f:\Project\AMH/muldataset/00004-2242/face_landmarks.csv
# There are 198.0 faces recorded from this sample.
# (92664,)
# (468,)
# (1035, 1404)
# f:\Project\AMH/muldataset/00004-2243/face_landmarks.csv
# There are 53.0 faces recorded from this sample.
# (24804,)
# (468,)
# (1036, 1404)
# f:\Project\AMH/muldataset/00004-2245/face_landmarks.csv
# There are 98.0 faces recorded from this sample.
# (45864,)
# (468,)
# (1037, 1404)
# f:\Project\AMH/muldataset/00004-2246/face_landmarks.csv
# There are 158.0 faces recorded from this sample.
# (73944,)
# (468,)
# (1038, 1404)
# f:\Project\AMH/muldataset/00004-2247/face_landmarks.csv
# There are 143.0 faces recorded from this sample.
# (66924,)
# (468,)
# (1039, 1404)
# f:\Project\AMH/muldataset/00004-2302/face_landmarks.csv
# There are 203.0 faces recorded from this sample.
# (95004,)
# (468,)
# (1040, 1404)
# f:\Project\AMH/muldataset/00004-2303/face_landmarks.csv
# There are 133.0 faces recorded from this sample.
# (62244,)
# (468,)
# (1041, 1404)
# f:\Project\AMH/muldataset/00004-2304/face_landmarks.csv
# There are 47.0 faces recorded from this sample.
# (21996,)
# (468,)
# (1042, 1404)
# f:\Project\AMH/muldataset/00004-2306/face_landmarks.csv
# There are 135.0 faces recorded from this sample.
# (63180,)
# (468,)
# (1043, 1404)
# f:\Project\AMH/muldataset/00004-2307/face_landmarks.csv
# There are 167.0 faces recorded from this sample.
# (78156,)
# (468,)
# (1044, 1404)
# f:\Project\AMH/muldataset/00004-2309/face_landmarks.csv
# There are 32.0 faces recorded from this sample.
# (14976,)
# (468,)
# (1045, 1404)
# f:\Project\AMH/muldataset/00004-2311/face_landmarks.csv
# There are 74.0 faces recorded from this sample.
# (34632,)
# (468,)
# (1046, 1404)
# f:\Project\AMH/muldataset/00004-2312/face_landmarks.csv
# There are 15.0 faces recorded from this sample.
# (7020,)
# (468,)
# (1047, 1404)
# f:\Project\AMH/muldataset/00004-2313/face_landmarks.csv
# There are 230.0 faces recorded from this sample.
# (107640,)
# (468,)
# (1048, 1404)
# f:\Project\AMH/muldataset/00004-2315/face_landmarks.csv
# There are 219.0 faces recorded from this sample.
# (102492,)
# (468,)
# (1049, 1404)
# f:\Project\AMH/muldataset/00004-2317/face_landmarks.csv
# There are 102.0 faces recorded from this sample.
# (47736,)
# (468,)
# (1050, 1404)
# f:\Project\AMH/muldataset/00004-2320/face_landmarks.csv
# There are 154.0 faces recorded from this sample.
# (72072,)
# (468,)
# (1051, 1404)
# f:\Project\AMH/muldataset/00004-2322/face_landmarks.csv
# There are 35.0 faces recorded from this sample.
# (16380,)
# (468,)
# (1052, 1404)
# f:\Project\AMH/muldataset/00004-2323/face_landmarks.csv
# There are 37.0 faces recorded from this sample.
# (17316,)
# (468,)
# (1053, 1404)
# f:\Project\AMH/muldataset/00004-2324/face_landmarks.csv
# There are 179.0 faces recorded from this sample.
# (83772,)
# (468,)
# (1054, 1404)
# f:\Project\AMH/muldataset/00004-2325/face_landmarks.csv
# There are 12.0 faces recorded from this sample.
# (5616,)
# (468,)
# (1055, 1404)
# f:\Project\AMH/muldataset/00004-2326/face_landmarks.csv
# There are 182.0 faces recorded from this sample.
# (85176,)
# (468,)
# (1056, 1404)
# f:\Project\AMH/muldataset/00004-2327/face_landmarks.csv
# There are 173.0 faces recorded from this sample.
# (80964,)
# (468,)
# (1057, 1404)
# f:\Project\AMH/muldataset/00004-2328/face_landmarks.csv
# There are 200.0 faces recorded from this sample.
# (93600,)
# (468,)
# (1058, 1404)
# f:\Project\AMH/muldataset/00004-2333/face_landmarks.csv
# There are 86.0 faces recorded from this sample.
# (40248,)
# (468,)
# (1059, 1404)
# f:\Project\AMH/muldataset/00004-2334/face_landmarks.csv
# There are 132.0 faces recorded from this sample.
# (61776,)
# (468,)
# (1060, 1404)
# f:\Project\AMH/muldataset/00004-2335/face_landmarks.csv
# There are 54.0 faces recorded from this sample.
# (25272,)
# (468,)
# (1061, 1404)
# f:\Project\AMH/muldataset/00004-2336/face_landmarks.csv
# There are 38.0 faces recorded from this sample.
# (17784,)
# (468,)
# (1062, 1404)
# f:\Project\AMH/muldataset/00004-2337/face_landmarks.csv
# There are 199.0 faces recorded from this sample.
# (93132,)
# (468,)
# (1063, 1404)
# f:\Project\AMH/muldataset/00004-2338/face_landmarks.csv
# There are 105.0 faces recorded from this sample.
# (49140,)
# (468,)
# (1064, 1404)
# f:\Project\AMH/muldataset/00004-2344/face_landmarks.csv
# There are 77.0 faces recorded from this sample.
# (36036,)
# (468,)
# (1065, 1404)
# f:\Project\AMH/muldataset/00004-2345/face_landmarks.csv
# There are 19.0 faces recorded from this sample.
# (8892,)
# (468,)
# (1066, 1404)
# f:\Project\AMH/muldataset/00004-2347/face_landmarks.csv
# There are 119.0 faces recorded from this sample.
# (55692,)
# (468,)
# (1067, 1404)
# f:\Project\AMH/muldataset/00004-2348/face_landmarks.csv
# There are 186.0 faces recorded from this sample.
# (87048,)
# (468,)
# (1068, 1404)
# f:\Project\AMH/muldataset/00004-2350/face_landmarks.csv
# There are 172.0 faces recorded from this sample.
# (80496,)
# (468,)
# (1069, 1404)
# f:\Project\AMH/muldataset/00004-2403/face_landmarks.csv
# There are 19.0 faces recorded from this sample.
# (8892,)
# (468,)
# (1070, 1404)
# f:\Project\AMH/muldataset/00004-2405/face_landmarks.csv
# There are 83.0 faces recorded from this sample.
# (38844,)
# (468,)
# (1071, 1404)
# f:\Project\AMH/muldataset/00004-2406/face_landmarks.csv
# There are 149.0 faces recorded from this sample.
# (69732,)
# (468,)
# (1072, 1404)
# f:\Project\AMH/muldataset/00004-2407/face_landmarks.csv
# There are 80.0 faces recorded from this sample.
# (37440,)
# (468,)
# (1073, 1404)
# f:\Project\AMH/muldataset/00004-2408/face_landmarks.csv
# There are 76.0 faces recorded from this sample.
# (35568,)
# (468,)
# (1074, 1404)
# f:\Project\AMH/muldataset/00004-2409/face_landmarks.csv
# There are 92.0 faces recorded from this sample.
# (43056,)
# (468,)
# (1075, 1404)
# f:\Project\AMH/muldataset/00004-2411/face_landmarks.csv
# There are 42.0 faces recorded from this sample.
# (19656,)
# (468,)
# (1076, 1404)
# f:\Project\AMH/muldataset/00004-2412/face_landmarks.csv
# There are 104.0 faces recorded from this sample.
# (48672,)
# (468,)
# (1077, 1404)
# f:\Project\AMH/muldataset/00004-2413/face_landmarks.csv
# There are 38.0 faces recorded from this sample.
# (17784,)
# (468,)
# (1078, 1404)
# f:\Project\AMH/muldataset/00004-2414/face_landmarks.csv
# There are 170.0 faces recorded from this sample.
# (79560,)
# (468,)
# (1079, 1404)
# f:\Project\AMH/muldataset/00004-2415/face_landmarks.csv
# There are 115.0 faces recorded from this sample.
# (53820,)
# (468,)
# (1080, 1404)
# f:\Project\AMH/muldataset/00004-2417/face_landmarks.csv
# There are 176.0 faces recorded from this sample.
# (82368,)
# (468,)
# (1081, 1404)
# f:\Project\AMH/muldataset/00004-2418/face_landmarks.csv
# There are 163.0 faces recorded from this sample.
# (76284,)
# (468,)
# (1082, 1404)
# f:\Project\AMH/muldataset/00004-2419/face_landmarks.csv
# There are 33.0 faces recorded from this sample.
# (15444,)
# (468,)
# (1083, 1404)
# f:\Project\AMH/muldataset/00004-2420/face_landmarks.csv
# There are 99.0 faces recorded from this sample.
# (46332,)
# (468,)
# (1084, 1404)
# f:\Project\AMH/muldataset/00004-2421/face_landmarks.csv
# There are 190.0 faces recorded from this sample.
# (88920,)
# (468,)
# (1085, 1404)
# f:\Project\AMH/muldataset/00004-2422/face_landmarks.csv
# There are 68.0 faces recorded from this sample.
# (31824,)
# (468,)
# (1086, 1404)
# f:\Project\AMH/muldataset/00004-2424/face_landmarks.csv
# There are 15.0 faces recorded from this sample.
# (7020,)
# (468,)
# (1087, 1404)
# f:\Project\AMH/muldataset/00004-2425/face_landmarks.csv
# There are 120.0 faces recorded from this sample.
# (56160,)
# (468,)
# (1088, 1404)
# f:\Project\AMH/muldataset/00004-2427/face_landmarks.csv
# There are 23.0 faces recorded from this sample.
# (10764,)
# (468,)
# (1089, 1404)
# f:\Project\AMH/muldataset/00004-2428/face_landmarks.csv
# There are 146.0 faces recorded from this sample.
# (68328,)
# (468,)
# (1090, 1404)
# f:\Project\AMH/muldataset/00004-2429/face_landmarks.csv
# There are 50.0 faces recorded from this sample.
# (23400,)
# (468,)
# (1091, 1404)
# f:\Project\AMH/muldataset/00004-2430/face_landmarks.csv
# There are 56.0 faces recorded from this sample.
# (26208,)
# (468,)
# (1092, 1404)
# f:\Project\AMH/muldataset/00004-2431/face_landmarks.csv
# There are 143.0 faces recorded from this sample.
# (66924,)
# (468,)
# (1093, 1404)
# f:\Project\AMH/muldataset/00004-2433/face_landmarks.csv
# There are 121.0 faces recorded from this sample.
# (56628,)
# (468,)
# (1094, 1404)
# f:\Project\AMH/muldataset/00004-2434/face_landmarks.csv
# There are 165.0 faces recorded from this sample.
# (77220,)
# (468,)
# (1095, 1404)
# f:\Project\AMH/muldataset/00004-2435/face_landmarks.csv
# There are 99.0 faces recorded from this sample.
# (46332,)
# (468,)
# (1096, 1404)
# f:\Project\AMH/muldataset/00004-2437/face_landmarks.csv
# There are 30.0 faces recorded from this sample.
# (14040,)
# (468,)
# (1097, 1404)
# f:\Project\AMH/muldataset/00004-2438/face_landmarks.csv
# There are 133.0 faces recorded from this sample.
# (62244,)
# (468,)
# (1098, 1404)
# f:\Project\AMH/muldataset/00004-2439/face_landmarks.csv
# There are 31.0 faces recorded from this sample.
# (14508,)
# (468,)
# (1099, 1404)
# f:\Project\AMH/muldataset/00004-2440/face_landmarks.csv
# There are 143.0 faces recorded from this sample.
# (66924,)
# (468,)
# (1100, 1404)
# f:\Project\AMH/muldataset/00004-2442/face_landmarks.csv
# There are 46.0 faces recorded from this sample.
# (21528,)
# (468,)
# (1101, 1404)
# f:\Project\AMH/muldataset/00004-2443/face_landmarks.csv
# There are 78.0 faces recorded from this sample.
# (36504,)
# (468,)
# (1102, 1404)
# f:\Project\AMH/muldataset/00004-2445/face_landmarks.csv
# There are 136.0 faces recorded from this sample.
# (63648,)
# (468,)
# (1103, 1404)
# f:\Project\AMH/muldataset/00004-2446/face_landmarks.csv
# There are 26.0 faces recorded from this sample.
# (12168,)
# (468,)
# (1104, 1404)
# f:\Project\AMH/muldataset/00004-2447/face_landmarks.csv
# There are 19.0 faces recorded from this sample.
# (8892,)
# (468,)
# (1105, 1404)
# f:\Project\AMH/muldataset/00004-2448/face_landmarks.csv
# There are 73.0 faces recorded from this sample.
# (34164,)
# (468,)
# (1106, 1404)
# f:\Project\AMH/muldataset/00004-2449/face_landmarks.csv
# There are 18.0 faces recorded from this sample.
# (8424,)
# (468,)
# (1107, 1404)
# (1107, 1404)
# (1107,)
